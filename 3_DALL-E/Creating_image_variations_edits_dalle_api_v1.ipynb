# %% [markdown]
# ## Creating Variations of an Image

# %%
import os
os.environ['OPENAI_API_KEY'] = ''

from openai import OpenAI
client = OpenAI()

image = open('original_1.png', 'rb')

response = client.images.create_variation(
    image=image,
    n=1,
    size='1024x1024'
)

image_url = response.data[0].url
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-IXBiBnJ5QPnEVI56pPwN085r/user-b6YryqNlJB2rQFSASGoFPuRw/img-zDBrWb6alAIOZHRGiQtPeWfC.png?st=2023-11-26T12%3A27%3A44Z&se=2023-11-26T14%3A27%3A44Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-11-26T01%3A01%3A33Z&ske=2023-11-27T01%3A01%3A33Z&sks=b&skv=2021-08-06&sig=M0toXYvI3VxKfJC34xquMJVoSDLFRzXArOU/0RRySHI%3D

# %% [markdown]
# ## Edit an Existing Image

# %%
import os
os.environ['OPENAI_API_KEY'] = ''
from openai import OpenAI

image = open('man_on_motorcycle.png', 'rb')
mask = open('mask.png', 'rb')

client = OpenAI()
response = client.images.edit(
    image=image,
    mask=mask,
    prompt='John Wick riding a motorcycle on an apocalyptic field containing a big red moon in a cyberpunk look,\
    high quality photography',
    n=1,
    size='1024x1024'
)

image_url = response.data[0].url
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-IXBiBnJ5QPnEVI56pPwN085r/user-b6YryqNlJB2rQFSASGoFPuRw/img-OFf8t7u1qoLHozyj3OtyS9k3.png?st=2023-11-26T12%3A53%3A48Z&se=2023-11-26T14%3A53%3A48Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-11-26T04%3A49%3A07Z&ske=2023-11-27T04%3A49%3A07Z&sks=b&skv=2021-08-06&sig=gcZcHYSVeaNwTGM/lR5TOqE1b29IDTYlMEhhPiqyDfQ%3D
